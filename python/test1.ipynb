# %%
import numpy as np

with open('test.npy', 'rb') as f:
    a = np.load(f)

# %%
a.shape
# Out:
# (2, 84, 84, 4)

# %%
from matplotlib import pyplot as plt
plt.imshow(a[1], interpolation='nearest')
plt.show()
plt.imshow(a[0], interpolation='nearest')
plt.show()

# %%
with open('test.npy', 'rb') as f:
    a = np.load(f)

plt.imshow(a[1], interpolation='nearest')
plt.show()
plt.imshow(a[0], interpolation='nearest')
plt.show()

# %%
with open('test.npy', 'rb') as f:
    a = np.load(f)

plt.imshow(a[1], interpolation='nearest')
plt.show()
plt.imshow(a[0], interpolation='nearest')
plt.show()

# %%
plt.imshow(a[0,:,:,0], interpolation='nearest')
plt.show()
plt.imshow(a[0,:,:,1], interpolation='nearest')
plt.show()
plt.imshow(a[0,:,:,2], interpolation='nearest')
plt.show()
plt.imshow(a[0,:,:,3], interpolation='nearest')
plt.show()

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() and args.cuda else "cpu")
b = torch.Tensor(a[0]).to(device).permute(2,0,1).numpy()
c = np.moveaxis(a,3,1)
np.array_equal(b,c[0])
b.shape
# Out:
# (4, 84, 84)

# %%
with open('test1.npy', 'rb') as f:
    a = np.load(f)

plt.imshow(a[1], interpolation='nearest')
plt.show()
plt.imshow(a[0], interpolation='nearest')
plt.show()

# %%
plt.imshow(a[0,:,:,0], interpolation='nearest')
plt.show()
plt.imshow(a[0,:,:,1], interpolation='nearest')
plt.show()
plt.imshow(a[0,:,:,2], interpolation='nearest')
plt.show()
plt.imshow(a[0,:,:,3], interpolation='nearest')
plt.show()

# %%
import numpy as np

with open('test.npy', 'rb') as f:
    a = np.load(f)

# %%
a.shape
# Out:
# (2, 84, 84, 4)

# %%
from matplotlib import pyplot as plt
plt.imshow(a[1], interpolation='nearest')
plt.show()
plt.imshow(a[0], interpolation='nearest')
plt.show()

# %%
with open('test.npy', 'rb') as f:
    a = np.load(f)

plt.imshow(a[1], interpolation='nearest')
plt.show()
plt.imshow(a[0], interpolation='nearest')
plt.show()

# %%
with open('test.npy', 'rb') as f:
    a = np.load(f)

plt.imshow(a[1], interpolation='nearest')
plt.show()
plt.imshow(a[0], interpolation='nearest')
plt.show()

# %%
fig = plt.figure(figsize=(16,10))
ax1 = fig.add_subplot(1,4,1)
ax1.imshow(a[0,:,:,0], interpolation='nearest')
ax2 = fig.add_subplot(1,4,2)
ax2.imshow(a[0,:,:,0], interpolation='nearest')
ax3 = fig.add_subplot(1,4,3)
ax3.imshow(a[0,:,:,0], interpolation='nearest')
ax4 = fig.add_subplot(1,4,4)
ax4.imshow(a[0,:,:,0], interpolation='nearest')

# %%
import torch
device = torch.device("cpu")
b = torch.Tensor(a[0:1]).to(device).permute((0,3,1,2)).numpy()
c = np.moveaxis(a[0:1],3,1)
np.array_equal(b,c)
# Out:
# True
